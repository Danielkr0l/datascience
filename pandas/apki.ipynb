# %% [markdown]
# <a href="https://colab.research.google.com/github/Danielkr0l/datascience/blob/main/pandas/apki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('appstore_games.csv')
df.head()
# Out:
#                                                  URL           ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427.0
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400.0
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595.0
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462.0
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220.0
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
dfc = df.copy()

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3197 entries, 0 to 3196
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           3197 non-null   object
#  1   ID                            3196 non-null   float64
#  2   Name                          3196 non-null   object
#  3   Subtitle                      493 non-null    object
#  4   Icon URL                      3196 non-null   object
#  5   Average User Rating           2515 non-null   float64
#  6   User Rating Count             2515 non-null   float64
#  7   Price                         3196 non-null   float64
#  8   In-app Purchases              1611 non-null   object
#  9   Description                   3196 non-null   object
#  10  Developer                     3196 non-null   object
#  11  Age Rating                    3196 non-null   object
# ...

# %%
dfc = dfc.drop(columns=['URL', 'Icon URL', 'Subtitle', 'Description', 'In-app Purchases'])
dfc
# Out:
#                ID                                               Name  \
# 0     284921427.0                                             Sudoku
# 1     284926400.0                                            Reversi
# 2     284946595.0                                            Morocco
# 3     285755462.0                                      Sudoku (Free)
# 4     285831220.0                                       Senet Deluxe
# ...           ...                                                ...
# 3192  798515299.0                           Bubble Match Mania Blaze
# 3193  799266767.0  Ships and Rockets Free - Retro Pixel Art TD Ar...
# 3194  799455799.0                  My Kingdom for the Princess IV HD
# 3195  799471892.0                          Out There: \u03a9 Edition
# 3196          NaN                                                NaN
#
#       Average User Rating  User Rating Count  Price  \
# 0                     4.0             3553.0   2.99
# ...

# %%
dfc = dfc.set_index('ID')
dfc
# Out:
#                                                           Name  \
# ID
# 284921427.0                                             Sudoku
# 284926400.0                                            Reversi
# 284946595.0                                            Morocco
# 285755462.0                                      Sudoku (Free)
# 285831220.0                                       Senet Deluxe
# ...                                                        ...
# 798515299.0                           Bubble Match Mania Blaze
# 799266767.0  Ships and Rockets Free - Retro Pixel Art TD Ar...
# 799455799.0                  My Kingdom for the Princess IV HD
# 799471892.0                          Out There: \u03a9 Edition
# NaN                                                        NaN
#
#              Average User Rating  User Rating Count  Price  \
# ID
# 284921427.0                  4.0             3553.0   2.99
# 284926400.0                  3.5              284.0   1.99
# ...

# %%
dfc.describe().T
# Out:
#                       count          mean           std      min          25%  \
# Average User Rating  2515.0  3.882505e+00  7.160592e-01      1.0         3.50
# User Rating Count    2515.0  4.997661e+03  6.388185e+04      5.0        20.00
# Price                3196.0  7.149155e-01  2.936028e+00      0.0         0.00
# Size                 3196.0  7.959186e+07  1.489797e+08  51328.0  17554653.25
#
#                             50%          75%           max
# Average User Rating         4.0         4.50  5.000000e+00
# User Rating Count         101.0       698.00  3.032734e+06
# Price                       0.0         0.99  1.399900e+02
# Size                 38596172.0  84065792.00  3.747743e+09

# %%
dfc.describe(include = ['object']).T
# Out:
#                              count unique                      top  freq
# Name                          3196   3164                 Golden 4     2
# Developer                     3196   1728                 GabySoft    33
# Age Rating                    3196      4                       4+  2212
# Languages                     3189    336                       EN  2054
# Primary Genre                 3196     14                    Games  3046
# Genres                        3196    380  Games, Strategy, Puzzle   105
# Original Release Date         3196   1312               21/12/2011    20
# Current Version Release Date  3196   1687               24/07/2019    13

# %%
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
dfc.columns = [col.lower().replace(' ', '_') for col in dfc.columns]
dfc.head()
# Out:
#                       name  average_user_rating  user_rating_count  price  \
# ID
# 284921427.0         Sudoku                  4.0             3553.0   2.99
# 284926400.0        Reversi                  3.5              284.0   1.99
# 284946595.0        Morocco                  3.0             8376.0   0.00
# 285755462.0  Sudoku (Free)                  3.5           190394.0   0.00
# 285831220.0   Senet Deluxe                  3.5               28.0   2.99
#
#                             developer age_rating  \
# ID
# 284921427.0  Mighty Mighty Good Games         4+
# 284926400.0          Kiss The Machine         4+
# 284946595.0               Bayou Games         4+
# 285755462.0  Mighty Mighty Good Games         4+
# 285831220.0           RoGame Software         4+
#
#                                                      languages        size  \
# ID
# 284921427.0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# ...

# %%
dfc.head(2)
# Out:
#                 name  average_user_rating  user_rating_count  price  \
# ID
# 284921427.0   Sudoku                  4.0             3553.0   2.99
# 284926400.0  Reversi                  3.5              284.0   1.99
#
#                             developer age_rating  \
# ID
# 284921427.0  Mighty Mighty Good Games         4+
# 284926400.0          Kiss The Machine         4+
#
#                                                      languages        size  \
# ID
# 284921427.0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0
# 284926400.0                                                 EN  12328960.0
#
#             primary_genre                   genres original_release_date  \
# ID
# 284921427.0         Games  Games, Strategy, Puzzle            11/07/2008
# 284926400.0         Games   Games, Strategy, Board            11/07/2008
#
#             current_version_release_date
# ID
# 284921427.0                   30/05/2017
# 284926400.0                   17/05/2018

# %%
dfc.primary_genre.value_counts()
# Out:
# Games            3046
# Entertainment      58
# Education          31
# Utilities          22
# Sports             13
# Reference           7
# Finance             4
# Productivity        4
# Business            3
# Medical             2
# Book                2
# News                2
# Travel              1
# Lifestyle           1
# Name: primary_genre, dtype: int64

# %%
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df['Primary Genre'].value_counts()
# Out:
# Games            3046
# Entertainment      58
# Education          31
# Utilities          22
# Sports             13
# Reference           7
# Finance             4
# Productivity        4
# Business            3
# Medical             2
# Book                2
# News                2
# Travel              1
# Lifestyle           1
# Name: Primary Genre, dtype: int64

# %%
dfc.primary_genre.value_counts().nlargest(5)
# Out:
# Games            3046
# Entertainment      58
# Education          31
# Utilities          22
# Sports             13
# Name: primary_genre, dtype: int64

# %%
list(dfc.primary_genre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Entertainment', 'Education', 'Utilities', 'Sports']

# %%
dfc.age_rating.value_counts()
# Out:
# 4+     2212
# 9+      528
# 12+     385
# 17+      71
# Name: age_rating, dtype: int64

# %%
import seaborn as sns
sns.set()

_ = dfc.age_rating.value_counts().plot(kind = 'bar')

# %%
dfc.age_rating.value_counts().plot(kind = 'pie')

# %%
dfc.price.value_counts()
# Out:
# 0.00      2383
# 0.99       317
# 1.99       163
# 2.99       152
# 4.99        72
# 3.99        51
# 9.99        15
# 5.99        14
# 6.99        10
# 7.99         8
# 8.99         5
# 19.99        2
# 11.99        2
# 139.99       1
# 12.99        1
# Name: price, dtype: int64

# %%
dfc.average_user_rating.value_counts()
# Out:
# 4.5    812
# 4.0    684
# 3.5    442
# 3.0    249
# 2.5    132
# 5.0    123
# 2.0     56
# 1.5     13
# 1.0      4
# Name: average_user_rating, dtype: int64

# %%
dfc.languages.value_counts()
# Out:
# EN                                        2054
# EN, ZH                                      61
# EN, DE                                      56
# EN, ZH, ZH                                  55
# EN, JA                                      48
#                                           ...
# EN, FR, DE, HU, IT, PL, RU, ES, SV, TH       1
# EN, FR, ZH                                   1
# NL, EN, FR, DE, IT, JA, RU, ZH, ES, SV       1
# EN, FR, DE, IT, PL, PT, RU, ES, SV           1
# EN, FR, DE, PT, RU, ZH, ES                   1
# Name: languages, Length: 336, dtype: int64

# %%
dfc.languages.str.split(', ')
# Out:
# ID
# 284921427.0    [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 284926400.0                                                 [EN]
# 284946595.0                                                 [EN]
# 285755462.0    [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, P...
# 285831220.0    [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, R...
#                                      ...
# 798515299.0                                                 [EN]
# 799266767.0                                                 [EN]
# 799455799.0                                             [EN, RU]
# 799471892.0                         [EN, FR, DE, PT, RU, ZH, ES]
# NaN                                                          NaN
# Name: languages, Length: 3197, dtype: object

# %%
dfc.languages.str.split(', ').str.len()
# Out:
# ID
# 284921427.0    17.0
# 284926400.0     1.0
# 284946595.0     1.0
# 285755462.0    17.0
# 285831220.0    15.0
#                ...
# 798515299.0     1.0
# 799266767.0     1.0
# 799455799.0     2.0
# 799471892.0     7.0
# NaN             NaN
# Name: languages, Length: 3197, dtype: float64

# %%
dfc['lang'] = dfc.languages.str.split(', ').str.len()
dfc
# Out:
#                                                           name  \
# ID
# 284921427.0                                             Sudoku
# 284926400.0                                            Reversi
# 284946595.0                                            Morocco
# 285755462.0                                      Sudoku (Free)
# 285831220.0                                       Senet Deluxe
# ...                                                        ...
# 798515299.0                           Bubble Match Mania Blaze
# 799266767.0  Ships and Rockets Free - Retro Pixel Art TD Ar...
# 799455799.0                  My Kingdom for the Princess IV HD
# 799471892.0                          Out There: \u03a9 Edition
# NaN                                                        NaN
#
#              average_user_rating  user_rating_count  price  \
# ID
# 284921427.0                  4.0             3553.0   2.99
# 284926400.0                  3.5              284.0   1.99
# ...

# %%
dfc.lang.value_counts()
# Out:
# 1.0     2069
# 2.0      277
# 3.0      138
# 4.0      106
# 5.0      102
# 6.0       67
# 8.0       45
# 16.0      40
# 9.0       38
# 11.0      34
# 10.0      32
# 7.0       28
# 25.0      28
# 15.0      20
# 13.0      19
# 12.0      18
# 22.0      18
# 30.0      13
# 17.0      12
# 14.0      10
# 18.0      10
# 31.0      10
# 24.0       8
# 26.0       7
# 33.0       6
# 32.0       5
# 20.0       5
# 29.0       4
# 19.0       4
# 21.0       4
# 65.0       4
# 23.0       3
# 36.0       2
# 27.0       1
# 66.0       1
# 48.0       1
# Name: lang, dtype: int64

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3197 entries, 284921427.0 to nan
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          3196 non-null   object
#  1   average_user_rating           2515 non-null   float64
#  2   user_rating_count             2515 non-null   float64
#  3   price                         3196 non-null   float64
#  4   developer                     3196 non-null   object
#  5   age_rating                    3196 non-null   object
#  6   languages                     3189 non-null   object
#  7   size                          3196 non-null   float64
#  8   primary_genre                 3196 non-null   object
#  9   genres                        3196 non-null   object
#  10  original_release_date         3196 non-null   object
#  11  current_version_release_date  3196 non-null   object
# ...

# %%
dfc.average_user_rating.value_counts()
# Out:
# 4.5    812
# 4.0    684
# 3.5    442
# 3.0    249
# 2.5    132
# 5.0    123
# 2.0     56
# 1.5     13
# 1.0      4
# Name: average_user_rating, dtype: int64

# %%
dfc.average_user_rating.value_counts(dropna = False)
# Out:
# 4.5    812
# 4.0    684
# NaN    682
# 3.5    442
# 3.0    249
# 2.5    132
# 5.0    123
# 2.0     56
# 1.5     13
# 1.0      4
# Name: average_user_rating, dtype: int64

# %%
dfc.isnull()
# Out:
#               name  average_user_rating  user_rating_count  price  developer  \
# ID
# 284921427.0  False                False              False  False      False
# 284926400.0  False                False              False  False      False
# 284946595.0  False                False              False  False      False
# 285755462.0  False                False              False  False      False
# 285831220.0  False                False              False  False      False
# ...            ...                  ...                ...    ...        ...
# 798515299.0  False                False              False  False      False
# 799266767.0  False                False              False  False      False
# 799455799.0  False                False              False  False      False
# 799471892.0  False                False              False  False      False
# NaN           True                 True               True   True       True
#
# ...

# %%
dfc.isnull().sum()
# Out:
# name                              1
# average_user_rating             682
# user_rating_count               682
# price                             1
# developer                         1
# age_rating                        1
# languages                         8
# size                              1
# primary_genre                     1
# genres                            1
# original_release_date             1
# current_version_release_date      1
# lang                              8
# dtype: int64

# %%
dfc = dfc.dropna()
dfc.isnull().sum()
# Out:
# name                            0
# average_user_rating             0
# user_rating_count               0
# price                           0
# developer                       0
# age_rating                      0
# languages                       0
# size                            0
# primary_genre                   0
# genres                          0
# original_release_date           0
# current_version_release_date    0
# lang                            0
# dtype: int64
